# %% [markdown]
# # Data Visulaization using Seaborn.

# %% [markdown]
# Seaborn is a library that uses Matplotlib underneath to plot graphs.
# It will be used to visualize random distributions.

# %%
# importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
#%matplotlib inline

# %%
# %pip install -U seaborn

# %%
# getting the builtin datasets of seaborn.
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# loading dataset 
dataset_path = 'athlete_events.csv'

# Load the dataset into a Pandas DataFrame
df = pd.read_csv(dataset_path)

# Display the first few rows of the DataFrame to verify the loading
df.head()
#load_dataset=normally we use read_csv to read files but seaborn has some builtin files so top read these inbuiuld files we use load _dataset
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#To show dataset
df # SL,SW,PL,PW are the characteristics/features of Iris flower
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#print the first five rows of sataset to get the overview
print(df.head())
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#give the main overview of the dataset mainly column names, non null count and data type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
#print the table of numerical values like mean and standard deviation
df.describe() #numerical
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#show coloumns in dataset
df.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
#generate descriptive statistics of the categorical (object) columns
# giving the count, unique numbers and most frquently occuring values
df.describe(include="O") #Categorical
# Out:
#                         Name     Sex           Team     NOC        Games  \
# count                 271116  271116         271116  271116       271116
# unique                134732       2           1184     230           51
# top     Robert Tait McKenzie       M  United States     USA  2000 Summer
# freq                      58  196594          17847   18853        13821
#
#         Season    City      Sport                    Event  Medal
# count   271116  271116     271116                   271116  39783
# unique       2      42         66                      765      3
# top     Summer  London  Athletics  Football Men's Football   Gold
# freq    222552   22426      38624                     5733  13372

# %%
#giving the shape of the dataset(rows, columns)
df.shape
# Out:
# (271116, 15)

# %%
#print Events occured in olympics
df.Event.unique()
# Out:
# array(["Basketball Men's Basketball", "Judo Men's Extra-Lightweight",
#        "Football Men's Football", "Tug-Of-War Men's Tug-Of-War",
#        "Speed Skating Women's 500 metres",
#        "Speed Skating Women's 1,000 metres",
#        "Cross Country Skiing Men's 10 kilometres",
#        "Cross Country Skiing Men's 50 kilometres",
#        "Cross Country Skiing Men's 10/15 kilometres Pursuit",
#        "Cross Country Skiing Men's 4 x 10 kilometres Relay",
#        "Cross Country Skiing Men's 30 kilometres",
#        "Athletics Women's 100 metres",
#        "Athletics Women's 4 x 100 metres Relay",
#        "Ice Hockey Men's Ice Hockey",
#        "Swimming Men's 400 metres Freestyle", "Badminton Men's Singles",
#        "Sailing Women's Windsurfer",
#        "Biathlon Women's 7.5 kilometres Sprint",
#        "Swimming Men's 200 metres Breaststroke",
#        "Swimming Men's 400 metres Breaststroke",
#        "Gymnastics Men's Individual All-Around",
# ...

# %%
#print the values counts in the column
df.Sport.value_counts()
# Out:
# Sport
# Athletics        38624
# Gymnastics       26707
# Swimming         23195
# Shooting         11448
# Cycling          10859
#                  ...
# Racquets            12
# Jeu De Paume        11
# Roque                4
# Basque Pelota        2
# Aeronautics          1
# Name: count, Length: 66, dtype: int64

# %%
#print uniques Sport played in the olympics
df.Sport.unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
#print number of rows of species value count
df.Medal.value_counts()
# Out:
# Medal
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: count, dtype: int64

# %% [markdown]
# ### Step:3-EDA(Evaluatory Data Analysis)

# %%
### to show Line plot 
sns.lineplot(x='Year',y='Medal',data=df)#hue='Season')
plt.title("Lineplot")
plt.show()

# %%
### to show Line plot 
sns.lineplot(x='Age',y='Year',data=df,hue='Medal')
plt.title("Lineplot")
plt.show()

# %%
#to show dataset
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
## to show Scatter plot
sns.scatterplot(x = df['Weight'],y = df['Height'],hue = df['Medal'] ,style = df['Sex'] ,s=50)
plt.title('Weight vs Height')
plt.tight_layout()
plt.show()

# %%
#to show the dataset
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
## Bar plot
##A barplot is basically used to aggregate the categorical data 
#according to some methods and by default its the mean. 
##It can also be understood as a visualization of the group by action. 
#To use this plot we choose a categorical column for 
##the x axis and a numerical column for the y axis and we see that it 
# creates a plot taking a mean per categorical column. 

plt.figure(figsize=(15, 8))  # Adjust the figure size as needed

# Use seaborn barplot with 'hue' parameter
ax = sns.barplot(x='Year', y='Weight', data=df, hue='Medal')

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.show()
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
#to show barplot
sns.barplot(x='Age',y='Medal',data=df)
plt.show()

# %%
#to show barplot data for speal width column
sns.barplot(x=data.Age,y=data.Medal)
plt.show()

# %%
## Count Plot
##A countplot basically counts the categories and returns a 
# count of their occurrences. 
#countplot(use only for catogrical/numaercal descrit data)
sns.countplot(x='Medal',data=df)
plt.show()

# %%
#to show catplot
sns.catplot(x='Medal',y='Year',data=df)
plt.show()
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#to show catplot
sns.catplot(x='Age',y='Medal',data=df)
plt.show()
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## Box plot
##A boxplot is sometimes known as the box and whisker plot.It shows the 
#distribution of the quantitative data 
## that represents the comparisons between variables. boxplot shows the 
#quartiles of the dataset while the whiskers extend to
## show the rest of the distribution i.e. the dots indicating the 
#presence  of outliers.
sns.boxplot(x ='Age',data=df)
plt.show()

# %% [markdown]
# *Black horizontal line here is mean & black vertical line is median
# * Important Rule: If the percentage of outliers in the particular feature is more than 5% then we do not handle the outliers. We only handle them if the percentage of outliers is below 5%.   #eg-5(outliers)/150(total count here)=3.3%<5%

# %%
sns.boxplot(x='Medal', y='Weight', data=df)
plt.show()
# Checking outliers in each category with respect to sepal width.

# %%
#to show boxplot for petal width column
sns.boxplot(x='Medal',y='Age',data=df)
plt.show()

# %% [markdown]
# #### *Black horizontal line here is median & black vertical line is mean

# %%
#to show the numerical median value
np.median(data.Height)
# Out:
# nan

# %%
#to show the numerical mean value of petal length
np.mean(data.Year)
# Out:
# 1978.3784800601957

# %%
#to show the boxplot
sns.boxplot(x='Height',data=df)
plt.show()

# %%
## Violinplot
## It is similar to the boxplot except that it provides a higher,
## more advanced visualization and uses the kernel 
##density estimation to give a better description about the 
## data distribution.

sns.violinplot(x='Medal', y='Weight', data=df)
plt.show()
#violin plot=white dot in middle is median & black line in middle is dividing 50% data

# %%
#to show the voilin plot
sns.violinplot(x='Medal',y='Age',data=df)
plt.show()

# %%
##Stripplot
## It basically creates a scatter plot based on the category. 
# It is created using the stripplot()
plt.figure(figsize=(15, 8))  # Adjust the figure size as needed


ax= sns.stripplot(x='Sport', y='Age', data=df)

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.show()
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_19116\272052046.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
## Histogram
## A histogram is basically used to represent data provided in a form of 
# some groups.
## It is accurate method for the graphical representation of numerical data 
## distribution
sns.histplot(x='Medal', data=df)
plt.show()

# %%
#to show the histogram
plt.figure(figsize=(15, 8))  # Adjust the figure size as needed

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

sns.histplot(x="Weight",data=df,kde=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
plt.figure(figsize=(15, 8))  # Adjust the figure size as needed

#to show the histogram plot
ax = sns.histplot(x='Sport',data=df,hue='Medal',kde=True) #Bivariate=x,hue.......................................

# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

plt.show()
#kde is approximation of histogram to density curve.
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_19116\541541529.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

# %%
#to show the histogram plot
sns.histplot(x="Weight",data=df,kde=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
#print numerical mean value
np.mean(df.Year)
# Out:
# 1978.3784800601957

# %%
#print numerical median value
np.median(df.Year)
# Out:
# 1988.0

# %% [markdown]
# 1)Since mean not equal to median it is not normal distribution
# 2)Majority of flowers have petal length bw 1 to 1.6

# %%
## Distplot
## Distplot is used basically for UNIVARIATE set of observations
# and visualizes it through a histogram 
## i.e. only one observation and hence we choose one particular 
#column of the dataset
sns.displot(df['Age'],color="r",kde=True)
plt.show()
## density means the probability of given point to lie on the curve.
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Insight=The density os petal width is higher bw 0.1 to 0.5

# %%
#to give the numerical mean value
np.mean(data.petal_width)

# %%
#to give the numerical median value
np.median(data.)

# %%
#to show displot for specific column
plt.figure(figsize=(15, 8))  # Adjust the figure size as needed

sns.displot(df['Height'],kde=True)
# Rotate x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha='right')

plt.show()
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
##Pairplot
##Pairplot represents pairwise relation across the entire dataframe and supports an 

## additional  argument called hue for categorical separation. 
#What it does basically is create a jointplot between every possible numerical 
##column and takes a while if the dataframe is really huge

sns.pairplot(data=df,hue='Medal')
plt.show()
# Out:
# C:\Users\rahul\anaconda_3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# 1)Identifying business case & domain analysis
# 2)Basic checks
# 3)EDA
# 4)Data pre processing(Handling missing values,handling null values)
# 5)Feature Selection

# %% [markdown]
# # Step-5:Feature Selection

# %%
##Heat map
## Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
## In this, to represent more common values or higher activities brighter colors basically reddish colors are used and 
## to represent less common or activity values, darker colors are preferred

# correlation between the different parameters 
 # corr() finds coorelation bw columns ie if 2 or more colms are giving us similar information
    
    
temp_df = df.dropna(subset=['Medal'])
temp_df = temp_df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'Sport', 'Event', 'Medal'])
pt = temp_df.pivot_table(index='Sport', columns='Year', values='Medal', aggfunc='count', fill_value=0)

# Create a heatmap using Seaborn with different colors for each country
plt.figure(figsize=(12, 8))
sns.heatmap(pt, annot=True, cmap='viridis', fmt='g', linewidths=.5)  # You can use a different colormap, e.g., 'viridis'
plt.title('Medals Count by Sport and Year')
plt.xlabel('Year')
plt.ylabel('Sport')
plt.show()

# %% [markdown]
# * Important Rule: If the correlational value is more than or equal to 0.9/more than -0.9 then those features are set to be Highly correlated i.e both features are essentially giving us similar information. If 3 features/columns  have more than 0.9 than drop 2 of them
# #For above rule dont consider diagonal values which is 1, since for eg=sepal len colm is similar to sepal len colm only
